# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Read the dataset to python environment.

# %%
data = pd.read_excel('iris.xls')

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2. Display the columns in the dataset.

# %%
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
data['SL']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SL, Length: 150, dtype: float64

# %%
data['SW']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SW, Length: 150, dtype: float64

# %%
data['PL']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PL, Length: 150, dtype: float64

# %%
data['PW']
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: PW, Length: 150, dtype: float64

# %%
data['Classification']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Classification, Length: 150, dtype: object

# %% [markdown]
# # 3. Calculate the mean of each colum of the dataset.

# %%
data['SL'].mean()
# Out:
# 5.843333333333335

# %%
data['SW'].mean()
# Out:
# 3.0540000000000007

# %%
data['PL'].mean()
# Out:
# 3.7586666666666693

# %%
data['PW'].mean()
# Out:
# 1.1986666666666672

# %% [markdown]
# # 4. Check for null values present in the data set.

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.isna()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
data['Classification'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Classification, dtype: int64

# %% [markdown]
# # Box Plot

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.boxplot(x='Classification',y='SL',data=data)
plt.subplot(2,2,2)
sns.boxplot(x='Classification',y='SW',data=data)
plt.subplot(2,2,3)
sns.boxplot(x='Classification',y='PL',data=data)
plt.subplot(2,2,4)
sns.boxplot(x='Classification',y='PW',data=data)
pass

# %% [markdown]
# # Strip Plot

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.stripplot(x=data['Classification'],y=data['SL'],data=data,hue='Classification')
plt.subplot(2,2,2)
sns.stripplot(x=data['Classification'],y=data['SW'],data=data,hue='Classification')
plt.subplot(2,2,3)
sns.stripplot(x=data['Classification'],y=data['PL'],data=data,hue='Classification')
plt.subplot(2,2,4)
sns.stripplot(x=data['Classification'],y=data['PW'],data=data,hue='Classification')
pass

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(data.corr(),annot=True)
plt.xticks(rotation=90)
# Out:
# (array([0.5, 1.5, 2.5, 3.5]),
#  [Text(0.5, 0, 'SL'),
#   Text(1.5, 0, 'SW'),
#   Text(2.5, 0, 'PL'),
#   Text(3.5, 0, 'PW')])

# %% [markdown]
# # Violin Plot

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Classification',y='SL',data=data)
plt.subplot(2,2,2)
sns.violinplot(x='Classification',y='SW',data=data)
plt.subplot(2,2,3)
sns.violinplot(x='Classification',y='PL',data=data)
plt.subplot(2,2,4)
sns.violinplot(x='Classification',y='PW',data=data)
pass
